# %% [markdown]
# ## Basically adjusted code from Ola so that we use Optuna search

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import silhouette_score
from sklearn.mixture import GaussianMixture
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, FunctionTransformer, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import VarianceThreshold, SelectFromModel, RFE, mutual_info_classif, SelectKBest
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.decomposition import PCA
import optuna
import shap

X_train = pd.read_csv('data/x_train.txt', sep=r'\s+', header=None)
y_train = pd.read_csv('data/y_train.txt', sep=r'\s+', header=None).iloc[:,0]
X_test  = pd.read_csv('data/x_test.txt',  sep=r'\s+', header=None)

preprocessing = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler()),
    ('vthresh', VarianceThreshold(threshold=0.01)),
])

def net_score_cv(pipe, X, y, n_splits=5):
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    scores = []
    X_arr = X.values if hasattr(X, 'values') else X
    for tr, va in skf.split(X_arr, y):
        pl = pipe.fit(X_arr[tr], y.iloc[tr])
        probs = pl.predict_proba(X_arr[va])[:,1]
        top_idx = np.argsort(probs)[-1000:]
        tp = y.iloc[va].iloc[top_idx].sum()
        # number of features used
        if 'fs' in pipe.named_steps:
            fs = pipe.named_steps['fs']
            nf = fs.n_features_ if hasattr(fs, 'n_features_') else fs.get_support().sum()
        else:
            nf = X_arr.shape[1]
        scores.append(10 * tp - 200 * nf)
    return np.mean(scores)

def objective(trial):
    strategy = trial.suggest_categorical('strategy', ['logistic_l1', 'rf_kbest', 'xgb_shap', 'svm_uni', 'enet_rfe'])
    if strategy == 'logistic_l1':
        C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
        fs = SelectFromModel(LogisticRegression(penalty='l1', solver='saga', C=C, max_iter=5000), threshold='mean')
        clf = LogisticRegression(random_state=42)
        pipe = Pipeline([*preprocessing.steps, ('fs', fs), ('clf', clf)])

    elif strategy == 'rf_kbest':
        k = trial.suggest_int('rf_k', 5, 100)
        def rf_score(X, y):
            rf_full = RandomForestClassifier(n_estimators=200, random_state=42)
            rf_full.fit(X, y)
            return rf_full.feature_importances_
        fs = SelectKBest(rf_score, k=k)
        clf = RandomForestClassifier(n_estimators=trial.suggest_int('rf_n_est', 100, 500), random_state=42)
        pipe = Pipeline([*preprocessing.steps, ('fs', fs), ('clf', clf)])

    elif strategy == 'xgb_shap':
        k = trial.suggest_int('xgb_k', 5, 50)
        Xp = preprocessing.fit_transform(X_train)
        xgb_full = XGBClassifier(
            n_estimators=trial.suggest_int('xgb_n_est', 500, 2000),
            learning_rate=trial.suggest_loguniform('xgb_lr', 1e-3, 1e-1),
            max_depth=trial.suggest_int('xgb_md', 3, 8),
            tree_method='hist', random_state=42, use_label_encoder=False, eval_metric='logloss'
        )
        xgb_full.fit(Xp, y_train, eval_set=[(Xp, y_train)], verbose=False)
        expl = shap.TreeExplainer(xgb_full)
        shap_vals = expl.shap_values(Xp)
        mean_abs = np.abs(shap_vals).mean(axis=0)
        fs = SelectKBest(lambda X, y: mean_abs, k=k)
        clf = LogisticRegression(random_state=42)
        pipe = Pipeline([*preprocessing.steps, ('fs', fs), ('clf', clf)])

    elif strategy == 'svm_uni':
        k = trial.suggest_int('svm_k', 5, 100)
        C = trial.suggest_loguniform('svm_C', 1e-2, 1e2)
        gamma = trial.suggest_categorical('svm_gamma', ['scale','auto'])
        fs = SelectKBest(score_func=lambda X, y: mutual_info_classif(X, y, random_state=42), k=k)
        clf = SVC(kernel='rbf', C=C, gamma=gamma, probability=True, random_state=42)
        pipe = Pipeline([*preprocessing.steps, ('fs', fs), ('clf', clf)])

    else:
        n_feat = trial.suggest_int('enet_n', 5, 100)
        enet = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=trial.suggest_uniform('enet_l1', 0.0, 1.0), C=trial.suggest_loguniform('enet_C', 1e-4, 1e1), max_iter=5000, random_state=42)
        fs = RFE(estimator=enet, n_features_to_select=n_feat, step=0.1)
        clf = LogisticRegression(random_state=42)
        pipe = Pipeline([*preprocessing.steps, ('fs', fs), ('clf', clf)])

    score = net_score_cv(pipe, X_train, y_train)
    return score

study = optuna.create_study(direction='maximize', study_name='pipeline_net_score', sampler=optuna.samplers.TPESampler(seed=42), pruner=optuna.pruners.MedianPruner())
study.optimize(objective, n_trials=100, n_jobs=1)

print('Best strategy & hyperparams:', study.best_params)
print('Best net-score:', study.best_value)
# Out:
# [I 2025-05-27 23:58:39,868] A new study created in memory with name: pipeline_net_score
# [I 2025-05-28 00:00:13,500] Trial 0 finished with value: 1086.0 and parameters: {'strategy': 'rf_kbest', 'rf_k': 19, 'rf_n_est': 123}. Best is trial 0 with value: 1086.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   enet = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=trial.suggest_uniform('enet_l1', 0.0, 1.0), C=trial.suggest_loguniform('enet_C', 1e-4, 1e1), max_iter=5000, random_state=42)
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   enet = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=trial.suggest_uniform('enet_l1', 0.0, 1.0), C=trial.suggest_loguniform('enet_C', 1e-4, 1e1), max_iter=5000, random_state=42)
# [I 2025-05-28 00:00:21,158] Trial 1 finished with value: -11914.0 and parameters: {'strategy': 'enet_rfe', 'enet_n': 84, 'enet_l1': 0.21233911067827616, 'enet_C': 0.0008111941985431928}. Best is trial 0 with value: 1086.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:80: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate=trial.suggest_loguniform('xgb_lr', 1e-3, 1e-1),
# c:\Users\hucu\Desktop\AMLProject2\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:00:21] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-05-28 00:00:37,570] Trial 2 finished with value: -1714.0 and parameters: {'strategy': 'xgb_shap', 'xgb_k': 33, 'xgb_n_est': 709, 'xgb_lr': 0.00383962929980417, 'xgb_md': 5}. Best is trial 0 with value: 1086.0.
# [I 2025-05-28 00:02:18,478] Trial 3 finished with value: 3086.0 and parameters: {'strategy': 'rf_kbest', 'rf_k': 9, 'rf_n_est': 343}. Best is trial 3 with value: 3086.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:94: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('svm_C', 1e-2, 1e2)
# [I 2025-05-28 00:02:53,053] Trial 4 finished with value: -1914.0 and parameters: {'strategy': 'svm_uni', 'svm_k': 34, 'svm_C': 0.024586032763280065, 'svm_gamma': 'scale'}. Best is trial 3 with value: 3086.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:94: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('svm_C', 1e-2, 1e2)
# [I 2025-05-28 00:03:29,357] Trial 5 finished with value: -8714.0 and parameters: {'strategy': 'svm_uni', 'svm_k': 68, 'svm_C': 0.17654048052495078, 'svm_gamma': 'auto'}. Best is trial 3 with value: 3086.0.
# [I 2025-05-28 00:05:46,107] Trial 6 finished with value: -7514.0 and parameters: {'strategy': 'rf_kbest', 'rf_k': 62, 'rf_n_est': 469}. Best is trial 3 with value: 3086.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   enet = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=trial.suggest_uniform('enet_l1', 0.0, 1.0), C=trial.suggest_loguniform('enet_C', 1e-4, 1e1), max_iter=5000, random_state=42)
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   enet = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=trial.suggest_uniform('enet_l1', 0.0, 1.0), C=trial.suggest_loguniform('enet_C', 1e-4, 1e1), max_iter=5000, random_state=42)
# [I 2025-05-28 00:05:54,649] Trial 7 finished with value: -1314.0 and parameters: {'strategy': 'enet_rfe', 'enet_n': 31, 'enet_l1': 0.8287375091519293, 'enet_C': 0.0060780830996819525}. Best is trial 3 with value: 3086.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:94: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('svm_C', 1e-2, 1e2)
# [I 2025-05-28 00:06:36,734] Trial 8 finished with value: -14914.0 and parameters: {'strategy': 'svm_uni', 'svm_k': 99, 'svm_C': 12.273800987852969, 'svm_gamma': 'scale'}. Best is trial 3 with value: 3086.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:06:38,979] Trial 9 finished with value: 4606.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.006199100007802264}. Best is trial 9 with value: 4606.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:06:41,297] Trial 10 finished with value: 4606.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.006586252373799887}. Best is trial 9 with value: 4606.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:06:43,421] Trial 11 finished with value: 4646.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.00542318546635465}. Best is trial 11 with value: 4646.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:06:45,446] Trial 12 finished with value: 4646.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.005240077625245933}. Best is trial 11 with value: 4646.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:06:46,529] Trial 13 finished with value: -95114.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0001340501040366483}. Best is trial 11 with value: 4646.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:08:06,604] Trial 14 finished with value: -34474.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.4920709465227095}. Best is trial 11 with value: 4646.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:08:08,586] Trial 15 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.00256161684385224}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:80: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate=trial.suggest_loguniform('xgb_lr', 1e-3, 1e-1),
# c:\Users\hucu\Desktop\AMLProject2\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:08:08] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-05-28 00:08:55,885] Trial 16 finished with value: 3086.0 and parameters: {'strategy': 'xgb_shap', 'xgb_k': 9, 'xgb_n_est': 1984, 'xgb_lr': 0.0743230891283017, 'xgb_md': 8}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:08:57,160] Trial 17 finished with value: -95114.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0002674768130134525}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:09:15,377] Trial 18 finished with value: -32034.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.11820007216055074}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:14:19,801] Trial 19 finished with value: -35234.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 6.812981903007415}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:80: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate=trial.suggest_loguniform('xgb_lr', 1e-3, 1e-1),
# c:\Users\hucu\Desktop\AMLProject2\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:14:20] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-05-28 00:14:34,116] Trial 20 finished with value: -4914.0 and parameters: {'strategy': 'xgb_shap', 'xgb_k': 49, 'xgb_n_est': 1630, 'xgb_lr': 0.0010500227525990081, 'xgb_md': 3}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:14:35,913] Trial 21 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0030357752802693504}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:14:37,669] Trial 22 finished with value: -75154.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0013205082342191068}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:14:39,729] Trial 23 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0014223194216743177}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:14:40,996] Trial 24 finished with value: -95114.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0007638612216913273}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   enet = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=trial.suggest_uniform('enet_l1', 0.0, 1.0), C=trial.suggest_loguniform('enet_C', 1e-4, 1e1), max_iter=5000, random_state=42)
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   enet = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=trial.suggest_uniform('enet_l1', 0.0, 1.0), C=trial.suggest_loguniform('enet_C', 1e-4, 1e1), max_iter=5000, random_state=42)
# [I 2025-05-28 00:16:43,549] Trial 25 finished with value: 3486.0 and parameters: {'strategy': 'enet_rfe', 'enet_n': 7, 'enet_l1': 0.04643184223406549, 'enet_C': 9.551793982137914}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:16:50,476] Trial 26 finished with value: -22314.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.045250163395826264}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:16:51,979] Trial 27 finished with value: -95114.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0012004958509839797}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:16:56,013] Trial 28 finished with value: -5154.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.022488627212746127}. Best is trial 15 with value: 4686.0.
# [I 2025-05-28 00:18:32,247] Trial 29 finished with value: -14714.0 and parameters: {'strategy': 'rf_kbest', 'rf_k': 98, 'rf_n_est': 104}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:94: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('svm_C', 1e-2, 1e2)
# [I 2025-05-28 00:19:20,844] Trial 30 finished with value: 1686.0 and parameters: {'strategy': 'svm_uni', 'svm_k': 16, 'svm_C': 82.73749485522025, 'svm_gamma': 'auto'}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:19:22,728] Trial 31 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0021082369897123666}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:19:24,121] Trial 32 finished with value: -95114.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.001107413429596553}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   enet = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=trial.suggest_uniform('enet_l1', 0.0, 1.0), C=trial.suggest_loguniform('enet_C', 1e-4, 1e1), max_iter=5000, random_state=42)
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   enet = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=trial.suggest_uniform('enet_l1', 0.0, 1.0), C=trial.suggest_loguniform('enet_C', 1e-4, 1e1), max_iter=5000, random_state=42)
# [I 2025-05-28 00:25:09,393] Trial 33 finished with value: -13714.0 and parameters: {'strategy': 'enet_rfe', 'enet_n': 93, 'enet_l1': 0.9468049264135636, 'enet_C': 1.6019000073635765}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:80: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate=trial.suggest_loguniform('xgb_lr', 1e-3, 1e-1),
# c:\Users\hucu\Desktop\AMLProject2\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:25:09] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-05-28 00:25:29,782] Trial 34 finished with value: 3886.0 and parameters: {'strategy': 'xgb_shap', 'xgb_k': 5, 'xgb_n_est': 524, 'xgb_lr': 0.0891842397626713, 'xgb_md': 8}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:25:31,031] Trial 35 finished with value: -95114.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0003936305543228286}. Best is trial 15 with value: 4686.0.
# [I 2025-05-28 00:27:53,582] Trial 36 finished with value: -5714.0 and parameters: {'strategy': 'rf_kbest', 'rf_k': 53, 'rf_n_est': 500}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:27:55,327] Trial 37 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0029388432084774202}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   enet = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=trial.suggest_uniform('enet_l1', 0.0, 1.0), C=trial.suggest_loguniform('enet_C', 1e-4, 1e1), max_iter=5000, random_state=42)
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   enet = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=trial.suggest_uniform('enet_l1', 0.0, 1.0), C=trial.suggest_loguniform('enet_C', 1e-4, 1e1), max_iter=5000, random_state=42)
# [I 2025-05-28 00:27:56,929] Trial 38 finished with value: -6514.0 and parameters: {'strategy': 'enet_rfe', 'enet_n': 57, 'enet_l1': 0.4877763401574873, 'enet_C': 0.00012695246996231331}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:94: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('svm_C', 1e-2, 1e2)
# [I 2025-05-28 00:28:32,723] Trial 39 finished with value: -8514.0 and parameters: {'strategy': 'svm_uni', 'svm_k': 67, 'svm_C': 0.8538755652649656, 'svm_gamma': 'scale'}. Best is trial 15 with value: 4686.0.
# [I 2025-05-28 00:30:34,467] Trial 40 finished with value: -14714.0 and parameters: {'strategy': 'rf_kbest', 'rf_k': 98, 'rf_n_est': 258}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:30:36,357] Trial 41 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0022541010970886267}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:30:38,153] Trial 42 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0028071197339372546}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:30:41,919] Trial 43 finished with value: -1594.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.019079566513424948}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:30:43,135] Trial 44 finished with value: -95114.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0005169590779586496}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:30:44,901] Trial 45 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0026528191930356958}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:30:48,336] Trial 46 finished with value: 4326.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.010056878039914395}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:80: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate=trial.suggest_loguniform('xgb_lr', 1e-3, 1e-1),
# c:\Users\hucu\Desktop\AMLProject2\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:30:48] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-05-28 00:30:58,532] Trial 47 finished with value: -114.0 and parameters: {'strategy': 'xgb_shap', 'xgb_k': 25, 'xgb_n_est': 1150, 'xgb_lr': 0.01278465863139434, 'xgb_md': 3}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:94: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('svm_C', 1e-2, 1e2)
# [I 2025-05-28 00:31:35,921] Trial 48 finished with value: -14514.0 and parameters: {'strategy': 'svm_uni', 'svm_k': 97, 'svm_C': 0.010094931633979155, 'svm_gamma': 'auto'}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:31:37,837] Trial 49 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.002505311140920249}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:31:38,958] Trial 50 finished with value: -95114.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.00020301714408345082}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:31:40,646] Trial 51 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0024669613532651183}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:31:42,469] Trial 52 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0016295151658345106}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:31:43,803] Trial 53 finished with value: -95114.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0008328725930257427}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:31:47,223] Trial 54 finished with value: 4046.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.011533058921145964}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:31:49,039] Trial 55 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.003944683499171818}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:31:51,669] Trial 56 finished with value: 4566.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.007499548599484944}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   enet = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=trial.suggest_uniform('enet_l1', 0.0, 1.0), C=trial.suggest_loguniform('enet_C', 1e-4, 1e1), max_iter=5000, random_state=42)
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   enet = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=trial.suggest_uniform('enet_l1', 0.0, 1.0), C=trial.suggest_loguniform('enet_C', 1e-4, 1e1), max_iter=5000, random_state=42)
# [I 2025-05-28 00:34:21,912] Trial 57 finished with value: -6914.0 and parameters: {'strategy': 'enet_rfe', 'enet_n': 59, 'enet_l1': 0.6101245403956267, 'enet_C': 0.15808145281046274}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:34:23,236] Trial 58 finished with value: -95114.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0005839194327490568}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:34:25,312] Trial 59 finished with value: 4646.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.005007835979224446}. Best is trial 15 with value: 4686.0.
# [I 2025-05-28 00:36:09,423] Trial 60 finished with value: -1914.0 and parameters: {'strategy': 'rf_kbest', 'rf_k': 34, 'rf_n_est': 265}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:36:11,323] Trial 61 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0022212267296406354}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:36:13,207] Trial 62 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.003916937940044116}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:36:15,015] Trial 63 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0018620168941636587}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:36:16,941] Trial 64 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.003874133096115296}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:80: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate=trial.suggest_loguniform('xgb_lr', 1e-3, 1e-1),
# c:\Users\hucu\Desktop\AMLProject2\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:36:17] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-05-28 00:36:47,834] Trial 65 finished with value: -4914.0 and parameters: {'strategy': 'xgb_shap', 'xgb_k': 49, 'xgb_n_est': 1129, 'xgb_lr': 0.01888432543350898, 'xgb_md': 6}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:36:51,384] Trial 66 finished with value: 4366.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.009854394100354411}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:36:53,632] Trial 67 finished with value: 4606.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.005958702044003039}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:94: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('svm_C', 1e-2, 1e2)
# [I 2025-05-28 00:37:24,024] Trial 68 finished with value: 3886.0 and parameters: {'strategy': 'svm_uni', 'svm_k': 5, 'svm_C': 7.250527049170488, 'svm_gamma': 'scale'}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:37:25,404] Trial 69 finished with value: -95114.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0011406870164502826}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:37:26,609] Trial 70 finished with value: -95114.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.00034889506582970735}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:37:28,455] Trial 71 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.002925856102142887}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:37:30,537] Trial 72 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.001705248254444023}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:37:32,324] Trial 73 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0028846408573218007}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:37:33,350] Trial 74 finished with value: -95114.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.00010371804931541248}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   enet = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=trial.suggest_uniform('enet_l1', 0.0, 1.0), C=trial.suggest_loguniform('enet_C', 1e-4, 1e1), max_iter=5000, random_state=42)
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   enet = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=trial.suggest_uniform('enet_l1', 0.0, 1.0), C=trial.suggest_loguniform('enet_C', 1e-4, 1e1), max_iter=5000, random_state=42)
# [I 2025-05-28 00:38:20,461] Trial 75 finished with value: 3086.0 and parameters: {'strategy': 'enet_rfe', 'enet_n': 9, 'enet_l1': 0.4015862662707897, 'enet_C': 0.04519200822912904}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:38:21,833] Trial 76 finished with value: -95114.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0007701771187982383}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# c:\Users\hucu\Desktop\AMLProject2\venv\Lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# [I 2025-05-28 00:43:22,070] Trial 77 finished with value: -35274.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 7.420271591690599}. Best is trial 15 with value: 4686.0.
# [I 2025-05-28 00:45:37,754] Trial 78 finished with value: -9714.0 and parameters: {'strategy': 'rf_kbest', 'rf_k': 73, 'rf_n_est': 373}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:80: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate=trial.suggest_loguniform('xgb_lr', 1e-3, 1e-1),
# c:\Users\hucu\Desktop\AMLProject2\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:45:38] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-05-28 00:46:26,835] Trial 79 finished with value: 86.0 and parameters: {'strategy': 'xgb_shap', 'xgb_k': 24, 'xgb_n_est': 1507, 'xgb_lr': 0.001077693876739863, 'xgb_md': 6}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:48:11,892] Trial 80 finished with value: -34754.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.6682432797041125}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:48:13,719] Trial 81 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0022926470050515257}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:48:15,580] Trial 82 finished with value: -75154.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0013288910671516746}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:48:17,873] Trial 83 finished with value: 4606.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.005860842111634138}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:48:19,704] Trial 84 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.003297063302961527}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:48:21,161] Trial 85 finished with value: -95114.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.001039101299322592}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:94: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('svm_C', 1e-2, 1e2)
# [I 2025-05-28 00:48:54,742] Trial 86 finished with value: -2714.0 and parameters: {'strategy': 'svm_uni', 'svm_k': 38, 'svm_C': 0.15990831590916618, 'svm_gamma': 'auto'}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:48:58,157] Trial 87 finished with value: 1566.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.01628931278039878}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:48:59,896] Trial 88 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0018968803502205697}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:49:06,727] Trial 89 finished with value: -19274.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.03915991742135893}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:102: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   enet = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=trial.suggest_uniform('enet_l1', 0.0, 1.0), C=trial.suggest_loguniform('enet_C', 1e-4, 1e1), max_iter=5000, random_state=42)
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:102: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   enet = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=trial.suggest_uniform('enet_l1', 0.0, 1.0), C=trial.suggest_loguniform('enet_C', 1e-4, 1e1), max_iter=5000, random_state=42)
# [I 2025-05-28 00:49:15,351] Trial 90 finished with value: -2914.0 and parameters: {'strategy': 'enet_rfe', 'enet_n': 39, 'enet_l1': 0.713413871669081, 'enet_C': 0.0035590522004145613}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:49:17,058] Trial 91 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0029623672608598867}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:49:18,864] Trial 92 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.002321151130970511}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:49:20,759] Trial 93 finished with value: 4686.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.001555407154202553}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:49:22,905] Trial 94 finished with value: 4646.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.005203843087072969}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:49:24,199] Trial 95 finished with value: -95114.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0006143946826448802}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:49:26,796] Trial 96 finished with value: 4566.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.007705559904742234}. Best is trial 15 with value: 4686.0.
# [I 2025-05-28 00:51:08,685] Trial 97 finished with value: -2314.0 and parameters: {'strategy': 'rf_kbest', 'rf_k': 36, 'rf_n_est': 191}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:58: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   C = trial.suggest_loguniform('log_l1_C', 1e-4, 1e1)
# [I 2025-05-28 00:51:10,067] Trial 98 finished with value: -95114.0 and parameters: {'strategy': 'logistic_l1', 'log_l1_C': 0.0009742269833472061}. Best is trial 15 with value: 4686.0.
# C:\Users\hucu\AppData\Local\Temp\ipykernel_24196\3533853146.py:80: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate=trial.suggest_loguniform('xgb_lr', 1e-3, 1e-1),
# c:\Users\hucu\Desktop\AMLProject2\venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:51:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [I 2025-05-28 00:51:30,256] Trial 99 finished with value: -2314.0 and parameters: {'strategy': 'xgb_shap', 'xgb_k': 36, 'xgb_n_est': 932, 'xgb_lr': 0.004317621668216999, 'xgb_md': 5}. Best is trial 15 with value: 4686.0.
# Best strategy & hyperparams: {'strategy': 'logistic_l1', 'log_l1_C': 0.00256161684385224}
# Best net-score: 4686.0

# %%
def build_best_pipe(params):
    strat = params['strategy']
    steps = preprocessing.steps.copy()
    if strat == 'logistic_l1':
        fs  = SelectFromModel(
                  LogisticRegression(penalty='l1', solver='saga',
                                     C=params['log_l1_C'], max_iter=5000),
                  threshold='mean'
               )
        clf = LogisticRegression(random_state=42)
    elif strat == 'rf_kbest':
        fs  = SelectKBest(
                  lambda X,y: RandomForestClassifier(
                                  n_estimators=params['rf_n_est'],
                                  random_state=42
                              ).fit(X,y).feature_importances_,
                  k=params['rf_k']
               )
        clf = RandomForestClassifier(n_estimators=params['rf_n_est2'],
                                     random_state=42)
    elif strat == 'xgb_shap':
        Xp    = preprocessing.fit_transform(X_train)
        xgb_r = XGBClassifier(
                  n_estimators=params['xgb_n_est'],
                  learning_rate=params['xgb_lr'],
                  max_depth=params['xgb_md'],
                  tree_method='hist',
                  use_label_encoder=False,
                  eval_metric='logloss',
                  random_state=42
               )
        xgb_r.fit(Xp, y_train, verbose=False)
        expl  = shap.TreeExplainer(xgb_r)
        gain_arr = np.abs(expl.shap_values(Xp)).mean(axis=0)
        fs    = SelectKBest(lambda X,y: gain_arr, k=params['xgb_k'])
        clf   = LogisticRegression(random_state=42)
    elif strat == 'svm_uni':
        fs  = SelectKBest(
                  score_func=lambda X,y: mutual_info_classif(
                                             X,y,random_state=42
                                          ),
                  k=params['svm_k']
               )
        clf = SVC(kernel='rbf',
                  C=params['svm_C'],
                  gamma=params['svm_gamma'],
                  probability=True,
                  random_state=42)
    else:
        enet = LogisticRegression(
                   penalty='elasticnet',
                   solver='saga',
                   l1_ratio=params['enet_l1'],
                   C=params['enet_C'],
                   max_iter=5000,
                   random_state=42
               )
        fs   = RFE(estimator=enet,
                   n_features_to_select=params['enet_n'],
                   step=0.1)
        clf  = LogisticRegression(random_state=42)

    steps += [('fs', fs), ('clf', clf)]
    return Pipeline(steps)

best_pipe = build_best_pipe(study.best_params)

cv_score = net_score_cv(best_pipe, X_train, y_train)
print(f"Net‐score of Optuna pipeline (5-fold CV): {cv_score:.1f}")

best_pipe.fit(X_train, y_train)
probs = best_pipe.predict_proba(X_test)[:, 1]

top_idx = np.argsort(probs)[-1000:]
with open('STUDENTID_obs.txt','w') as f:
    for i in top_idx:
        f.write(f"{i}\n")

fs = best_pipe.named_steps['fs']
mask = fs.get_support() if hasattr(fs, 'get_support') else np.ones(X_train.shape[1], dtype=bool)
feat_idxs = np.where(mask)[0]
with open('STUDENTID_vars.txt','w') as f:
    for i in feat_idxs:
        f.write(f"{i}\n")
# Out:
# Net‐score of Optuna pipeline (5-fold CV): 4686.0
